# %%
import pytesseract
try:
    from PIL import Image
except ImportError:
    import Image
import cv2

image_path = "/home/shimw/project/200Human/体检报告/端木德强/端木德强体检报告.jpg"
img = cv2.imread(image_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
text = pytesseract.image_to_string(gray, lang='chi_sim', config="--esm 2")
text.split("\n")
# Out:
# ['全咱 今,                                      区9 10:53',
#  '',
#  '义                         健康体检报告',
#  '',
#  '华中农业大学医院',
#  '',
#  ' ',
#  '',
#  '健康体检评估报告',
#  '',
#  '尊敬的 。 端木德强先生',
#  '和您好!',
#  '感谢您对本医院的信赖和支持。现将您健康体检报告呈上。',
#  '健康体检报告分三个部分 :',
#  '第-部分 总检医生对体检中发现问题的汇总分析及建议',
#  '二部分 临床检验报告',
#  '第三部分 体格检查结果',
#  '华中农业大学医院祝您身体健康， 阔家幸福 !',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  '档案编号 ”D201604051303',
#  '姓 “名 端木德强',
#  '',
#  '性 别 男',
#  '',
#  '年 龄 。 45岁',
#  '',
#  '单 ”位 2023华农职工体检',
#  '部 门 ”生命科学技术学院',
#  '电话 18694067218',
#  '体检日期 2023-05-31',
#  '',
#  '倡导健康的生活方式,积极预防,拥抱健康生活 !',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  ' ',
#  '',
#  '华中农业大学医院体检评估报告',
#  '检查科室与检查项目情况',
#  '科室名称           是否已检                                   检查项目名称',
#  '视力检查室             是                                         视力检查',
#  '公卫科               是                                         餐后血糖',
# ...
